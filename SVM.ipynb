# %%
import pandas as pd

# %%
df = pd.read_csv("Aemf1.csv")

# %%
df.head()
# Out:
#         City       Price      Day     Room Type  Shared Room  Private Room  \
# 0  Amsterdam  194.033698  Weekday  Private room        False          True
# 1  Amsterdam  344.245776  Weekday  Private room        False          True
# 2  Amsterdam  264.101422  Weekday  Private room        False          True
# 3  Amsterdam  433.529398  Weekday  Private room        False          True
# 4  Amsterdam  485.552926  Weekday  Private room        False          True
#
#    Person Capacity  Superhost  Multiple Rooms  Business  Cleanliness Rating  \
# 0              2.0      False               1         0                10.0
# 1              4.0      False               0         0                 8.0
# 2              2.0      False               0         1                 9.0
# 3              4.0      False               0         1                 9.0
# 4              2.0       True               0         0                10.0
#
#    Guest Satisfaction  Bedrooms  City Center (km)  Metro Distance (km)  \
# 0                93.0         1          5.022964             2.539380
# 1                85.0         1          0.488389             0.239404
# 2                87.0         1          5.748312             3.651621
# 3                90.0         2          0.384862             0.439876
# 4                98.0         1          0.544738             0.318693
#
#    Attraction Index  Normalised Attraction Index  Restraunt Index  \
# 0         78.690379                     4.166708        98.253896
# 1        631.176378                    33.421209       837.280757
# 2         75.275877                     3.985908        95.386955
# 3        493.272534                    26.119108       875.033098
# 4        552.830324                    29.272733       815.305740
#
#    Normalised Restraunt Index
# 0                    6.846473
# 1                   58.342928
# 2                    6.646700
# 3                   60.973565
# 4                   56.811677

# %%
df.shape
# Out:
# (41714, 19)

# %%
df.isnull().sum()
# Out:
# City                           0
# Price                          0
# Day                            0
# Room Type                      0
# Shared Room                    0
# Private Room                   0
# Person Capacity                0
# Superhost                      0
# Multiple Rooms                 0
# Business                       0
# Cleanliness Rating             0
# Guest Satisfaction             0
# Bedrooms                       0
# City Center (km)               0
# Metro Distance (km)            0
# Attraction Index               0
# Normalised Attraction Index    0
# Restraunt Index                0
# Normalised Restraunt Index     0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
for i in df.columns:
    if df[i].dtypes=='float64' or df[i].dtypes=='int':
        sns.boxplot(df[i])
        print(i)
        plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Price
# Person Capacity
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Cleanliness Rating
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Guest Satisfaction
# City Center (km)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Metro Distance (km)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Attraction Index
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Normalised Attraction Index
# Restraunt Index
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Normalised Restraunt Index
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
columns_outliers=["Price","City Center (km)","Metro Distance (km)","Attraction Index",
                  "Normalised Attraction Index","Restraunt Index","Normalised Restraunt Index"]

# %%
columns_outliers
# Out:
# ['Price',
#  'City Center (km)',
#  'Metro Distance (km)',
#  'Attraction Index',
#  'Normalised Attraction Index',
#  'Restraunt Index',
#  'Normalised Restraunt Index']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28925 entries, 3 to 41713
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   City                         28925 non-null  object
#  1   Price                        28925 non-null  float64
#  2   Day                          28925 non-null  object
#  3   Room Type                    28925 non-null  object
#  4   Shared Room                  28925 non-null  bool
#  5   Private Room                 28925 non-null  bool
#  6   Person Capacity              28925 non-null  float64
#  7   Superhost                    28925 non-null  bool
#  8   Multiple Rooms               28925 non-null  int64
#  9   Business                     28925 non-null  int64
#  10  Cleanliness Rating           28925 non-null  float64
#  11  Guest Satisfaction           28925 non-null  float64
#  12  Bedrooms                     28925 non-null  int64
#  13  City Center (km)             28925 non-null  float64
#  14  Metro Distance (km)          28925 non-null  float64
#  15  Attraction Index             28925 non-null  float64
#  16  Normalised Attraction Index  28925 non-null  float64
#  17  Restraunt Index              28925 non-null  float64
#  18  Normalised Restraunt Index   28925 non-null  float64
# dtypes: bool(3), float64(10), int64(3), object(3)
# memory usage: 3.8+ MB

# %%
for col in columns_outliers:
 Q1=df[col].quantile(0.25)
 Q3=df[col].quantile(0.75)
 IQR= Q3-Q1
 lower_limit= Q1 - 1.5 *IQR
 upper_limit = Q3 + 1.5 * IQR
 df= df[(df[col]>=lower_limit) & (df[col]<=upper_limit)]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
for i in df.columns:
    if df[i].dtypes=='float64' or df[i].dtypes=='int':
        sns.boxplot(df[i])
        print(i)
        plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Price
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Person Capacity
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Cleanliness Rating
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Guest Satisfaction
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# City Center (km)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Metro Distance (km)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Attraction Index
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Normalised Attraction Index
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Restraunt Index
# Normalised Restraunt Index
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize = (10, 7))
sns.histplot(data = df, x = 'Price', hue = 'City', bins = 20, multiple = 'stack', kde = True)
plt.title('Price by City')
plt.xlabel('Price')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize = (10, 7))
sns.boxplot(x='Cleanliness Rating', y='Price', data = df)
plt.title('Price by Cleanliness Rating')
plt.ylabel('Price')
plt.xlabel('Cleanliness Rating')
# Out:
# Text(0.5, 0, 'Cleanliness Rating')

# %%
plt.figure(figsize = (10, 7))
sns.boxplot(x= "Bedrooms", y = "Price", data = df)
plt.title("Price by number of Bedrooms")
plt.ylabel("Price")
plt.xlabel("Bedrooms")
# Out:
# Text(0.5, 0, 'Bedrooms')

# %%
plt.figure(figsize= (10, 7))
sns.set_style('darkgrid')
sns.lineplot(x = "Guest Satisfaction", y = "Price", data = df, color = 'purple')
plt.title("Price by Guest Satisfaction")
plt.ylabel("Price")
plt.xlabel("Guest Satisfaction")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27253 entries, 6 to 41713
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   City                         27253 non-null  object
#  1   Price                        27253 non-null  float64
#  2   Day                          27253 non-null  object
#  3   Room Type                    27253 non-null  object
#  4   Shared Room                  27253 non-null  bool
#  5   Private Room                 27253 non-null  bool
#  6   Person Capacity              27253 non-null  float64
#  7   Superhost                    27253 non-null  bool
#  8   Multiple Rooms               27253 non-null  int64
#  9   Business                     27253 non-null  int64
#  10  Cleanliness Rating           27253 non-null  float64
#  11  Guest Satisfaction           27253 non-null  float64
#  12  Bedrooms                     27253 non-null  int64
#  13  City Center (km)             27253 non-null  float64
#  14  Metro Distance (km)          27253 non-null  float64
#  15  Attraction Index             27253 non-null  float64
#  16  Normalised Attraction Index  27253 non-null  float64
#  17  Restraunt Index              27253 non-null  float64
#  18  Normalised Restraunt Index   27253 non-null  float64
# dtypes: bool(3), float64(10), int64(3), object(3)
# memory usage: 3.6+ MB

# %%
df['City'] = le.fit_transform(df['City'])
df['Day'] = le.fit_transform(df['Day'])
df['Room Type'] = le.fit_transform(df['Room Type'])
df['Shared Room']

# %%
for col in df.columns:
    if df[col].dtypes == 'object' or df[col].dtypes == 'bool':
        df[col]=le.fit_transform(df[col])

# %%
df
# Out:
#        City       Price  Day  Room Type  Shared Room  Private Room  \
# 6         0  215.124317    0          1            0             1
# 9         0  276.521454    0          1            0             1
# 15        0  368.851499    0          1            0             1
# 23        0  377.287746    0          1            0             1
# 26        0  295.034331    0          1            0             1
# ...     ...         ...  ...        ...          ...           ...
# 41703     8  359.021107    1          1            0             1
# 41707     8  115.933899    1          1            0             1
# 41710     8  304.793960    1          0            0             0
# 41712     8  301.054157    1          1            0             1
# 41713     8  133.230489    1          1            0             1
#
#        Person Capacity  Superhost  Multiple Rooms  Business  \
# 6                  2.0          0               0         0
# 9                  2.0          0               1         0
# 15                 2.0          1               0         0
# 23                 2.0          0               0         0
# 26                 2.0          0               1         0
# ...                ...        ...             ...       ...
# 41703              5.0          0               0         1
# 41707              4.0          0               1         0
# 41710              2.0          0               0         0
# 41712              2.0          0               0         0
# 41713              4.0          1               1         0
#
#        Cleanliness Rating  Guest Satisfaction  Bedrooms  City Center (km)  \
# 6                    10.0                94.0         1          1.881092
# 9                    10.0                88.0         1          3.142361
# 15                   10.0                98.0         1          1.031101
# 23                   10.0                98.0         1          1.167492
# 26                   10.0                95.0         1          3.366019
# ...                   ...                 ...       ...               ...
# 41703                10.0               100.0         1          0.913670
# 41707                 9.0                94.0         1          3.041932
# 41710                 8.0                86.0         1          0.810205
# 41712                10.0                87.0         1          3.044100
# 41713                10.0                93.0         1          1.263932
#
#        Metro Distance (km)  Attraction Index  Normalised Attraction Index  \
# 6                 0.729747        200.167652                    10.599010
# 9                 0.924404        206.252862                    10.921226
# 15                0.557885        359.921932                    19.058105
# 23                0.983743        278.800595                    14.762677
# 26                0.225882        170.028697                     9.003133
# ...                    ...               ...                          ...
# 41703             0.318838        193.594641                    13.863971
# 41707             0.308192        109.751387                     7.859670
# 41710             0.100839        204.970121                    14.678608
# 41712             0.287435        109.236574                     7.822803
# 41713             0.480903        150.450381                    10.774264
#
#        Restraunt Index  Normalised Restraunt Index
# 6           242.765524                   16.916251
# 9           238.291258                   16.604478
# 15          439.950562                   30.656388
# 23          383.577893                   26.728259
# 26          217.155231                   15.131689
# ...                ...                         ...
# 41703       307.871919                    7.441146
# 41707       208.517887                    5.039797
# 41710       342.182813                    8.270427
# 41712       158.563398                    3.832416
# 41713       225.247293                    5.444140
#
# [27253 rows x 19 columns]

# %%
plt.figure(figsize = (15,8))
sns.heatmap(df.corr(), annot = True, cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %%
x = df.iloc[:, :-1]
x
# Out:
#        City       Price  Day  Room Type  Shared Room  Private Room  \
# 6         0  215.124317    0          1            0             1
# 9         0  276.521454    0          1            0             1
# 15        0  368.851499    0          1            0             1
# 23        0  377.287746    0          1            0             1
# 26        0  295.034331    0          1            0             1
# ...     ...         ...  ...        ...          ...           ...
# 41703     8  359.021107    1          1            0             1
# 41707     8  115.933899    1          1            0             1
# 41710     8  304.793960    1          0            0             0
# 41712     8  301.054157    1          1            0             1
# 41713     8  133.230489    1          1            0             1
#
#        Person Capacity  Superhost  Multiple Rooms  Business  \
# 6                  2.0          0               0         0
# 9                  2.0          0               1         0
# 15                 2.0          1               0         0
# 23                 2.0          0               0         0
# 26                 2.0          0               1         0
# ...                ...        ...             ...       ...
# 41703              5.0          0               0         1
# 41707              4.0          0               1         0
# 41710              2.0          0               0         0
# 41712              2.0          0               0         0
# 41713              4.0          1               1         0
#
#        Cleanliness Rating  Guest Satisfaction  Bedrooms  City Center (km)  \
# 6                    10.0                94.0         1          1.881092
# 9                    10.0                88.0         1          3.142361
# 15                   10.0                98.0         1          1.031101
# 23                   10.0                98.0         1          1.167492
# 26                   10.0                95.0         1          3.366019
# ...                   ...                 ...       ...               ...
# 41703                10.0               100.0         1          0.913670
# 41707                 9.0                94.0         1          3.041932
# 41710                 8.0                86.0         1          0.810205
# 41712                10.0                87.0         1          3.044100
# 41713                10.0                93.0         1          1.263932
#
#        Metro Distance (km)  Attraction Index  Normalised Attraction Index  \
# 6                 0.729747        200.167652                    10.599010
# 9                 0.924404        206.252862                    10.921226
# 15                0.557885        359.921932                    19.058105
# 23                0.983743        278.800595                    14.762677
# 26                0.225882        170.028697                     9.003133
# ...                    ...               ...                          ...
# 41703             0.318838        193.594641                    13.863971
# 41707             0.308192        109.751387                     7.859670
# 41710             0.100839        204.970121                    14.678608
# 41712             0.287435        109.236574                     7.822803
# 41713             0.480903        150.450381                    10.774264
#
#        Restraunt Index
# 6           242.765524
# 9           238.291258
# 15          439.950562
# 23          383.577893
# 26          217.155231
# ...                ...
# 41703       307.871919
# 41707       208.517887
# 41710       342.182813
# 41712       158.563398
# 41713       225.247293
#
# [27253 rows x 18 columns]

# %%
y = df.iloc[:, -1]
y
# Out:
# 6        16.916251
# 9        16.604478
# 15       30.656388
# 23       26.728259
# 26       15.131689
#            ...
# 41703     7.441146
# 41707     5.039797
# 41710     8.270427
# 41712     3.832416
# 41713     5.444140
# Name: Normalised Restraunt Index, Length: 27253, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 34)

# %%
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.svm import SVR
svr = SVR()
svr.fit(x_train, y_train)
y_pred = svr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9089990624125721
